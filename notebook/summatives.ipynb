# %%
import pandas as pd

# %%
raw_data = pd.read_csv('this_might_be_the_data.csv')

# %%
raw_data
# Out:
#        Total Household Income              Region  Total Food Expenditure  \
# 0                      480332                 CAR                  117848
# 1                      198235                 CAR                   67766
# 2                       82785                 CAR                   61609
# 3                      107589                 CAR                   78189
# 4                      189322                 CAR                   94625
# ...                       ...                 ...                     ...
# 41539                  119773  XII - SOCCSKSARGEN                   44875
# 41540                  137320  XII - SOCCSKSARGEN                   31157
# 41541                  133171  XII - SOCCSKSARGEN                   45882
# 41542                  129500  XII - SOCCSKSARGEN                   81416
# 41543                  128598  XII - SOCCSKSARGEN                   78195
#
#             Main Source of Income  Agricultural Household indicator  \
# ...

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41544 entries, 0 to 41543
# Data columns (total 60 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Total Household Income                         41544 non-null  int64
#  1   Region                                         41544 non-null  object
#  2   Total Food Expenditure                         41544 non-null  int64
#  3   Main Source of Income                          41544 non-null  object
#  4   Agricultural Household indicator               41544 non-null  int64
#  5   Bread and Cereals Expenditure                  41544 non-null  int64
#  6   Total Rice Expenditure                         41544 non-null  int64
#  7   Meat Expenditure                               41544 non-null  int64
#  8   Total Fish and  marine products Expenditure    41544 non-null  int64
# ...

# %%
raw_data.shape
# Out:
# (41544, 60)

# %%
raw_data.dtypes
# Out:
# Total Household Income                            int64
# Region                                           object
# Total Food Expenditure                            int64
# Main Source of Income                            object
# Agricultural Household indicator                  int64
# Bread and Cereals Expenditure                     int64
# Total Rice Expenditure                            int64
# Meat Expenditure                                  int64
# Total Fish and  marine products Expenditure       int64
# Fruit Expenditure                                 int64
# Vegetables Expenditure                            int64
# Restaurant and hotels Expenditure                 int64
# Alcoholic Beverages Expenditure                   int64
# Tobacco Expenditure                               int64
# Clothing, Footwear and Other Wear Expenditure     int64
# Housing and water Expenditure                     int64
# Imputed House Rental Value                        int64
# ...

# %%
raw_data.describe()
# Out:
#        Total Household Income  Total Food Expenditure  \
# count            4.154400e+04            41544.000000
# mean             2.475556e+05            85099.158194
# std              2.868805e+05            51637.947682
# min              1.128500e+04             2947.000000
# 25%              1.048950e+05            51017.250000
# 50%              1.640795e+05            72985.500000
# 75%              2.911385e+05           105635.500000
# max              1.181599e+07           827565.000000
#
#        Agricultural Household indicator  Bread and Cereals Expenditure  \
# count                      41544.000000                   41544.000000
# mean                           0.429858                   25133.723642
# std                            0.676666                   13466.482984
# min                            0.000000                       0.000000
# 25%                            0.000000                   16556.000000
# ...

# %%
raw_data.isnull().sum()
# Out:
# Total Household Income                              0
# Region                                              0
# Total Food Expenditure                              0
# Main Source of Income                               0
# Agricultural Household indicator                    0
# Bread and Cereals Expenditure                       0
# Total Rice Expenditure                              0
# Meat Expenditure                                    0
# Total Fish and  marine products Expenditure         0
# Fruit Expenditure                                   0
# Vegetables Expenditure                              0
# Restaurant and hotels Expenditure                   0
# Alcoholic Beverages Expenditure                     0
# Tobacco Expenditure                                 0
# Clothing, Footwear and Other Wear Expenditure       0
# Housing and water Expenditure                       0
# Imputed House Rental Value                          0
# ...

# %%
raw_data['Total Income'] = raw_data['Total Household Income'] + raw_data['Total Income from Entrepreneurial Acitivites']

# %%
relevant_columns = ['Total Food Expenditure', 'Bread and Cereals Expenditure', 'Total Rice Expenditure', 'Meat Expenditure', 'Total Fish and  marine products Expenditure', 'Fruit Expenditure', 'Vegetables Expenditure']

corr_matrix = raw_data[relevant_columns].corr()

corr_matrix
# Out:
#                                              Total Food Expenditure  \
# Total Food Expenditure                                     1.000000
# Bread and Cereals Expenditure                              0.600319
# Total Rice Expenditure                                     0.435908
# Meat Expenditure                                           0.771272
# Total Fish and  marine products Expenditure                0.605594
# Fruit Expenditure                                          0.526141
# Vegetables Expenditure                                     0.556082
#
#                                              Bread and Cereals Expenditure  \
# Total Food Expenditure                                            0.600319
# Bread and Cereals Expenditure                                     1.000000
# Total Rice Expenditure                                            0.876286
# Meat Expenditure                                                  0.346779
# ...

# %%
food_cols = ['Bread and Cereals Expenditure', 'Total Rice Expenditure', 'Meat Expenditure', 
             'Total Fish and  marine products Expenditure', 'Fruit Expenditure', 'Vegetables Expenditure']

food_sum = raw_data[food_cols].sum(axis=1)
diff = raw_data['Total Household Income'] - food_sum
diff

raw_data[['Total Household Income', 'Total Income']].head(20)
# Out:
#     Total Household Income  Total Income
# 0                   480332        524702
# 1                   198235        198235
# 2                    82785         82785
# 3                   107589        123169
# 4                   189322        265009
# 5                   152883        152883
# 6                   198621        270911
# 7                   134961        186801
# 8                   171152        171152
# 9                   625753        938727
# 10                  147005        241145
# 11                  253130        342890
# 12                  101111        150856
# 13                  128214        187089
# 14                   91525        125065
# 15                  171742        190982
# 16                   95385        130860
# 17                  142843        180736
# 18                   88170        130360
# 19                   97018        174856

# %%
raw_data[['Household Head Sex', 'Household Head Age',
          'Household Head Marital Status',
          'Household Head Highest Grade Completed',
          'Household Head Job or Business Indicator',
          'Household Head Occupation',
          'Household Head Class of Worker',
          'Type of Household',
          'Total Number of Family members'
         ]].head()
# Out:
#   Household Head Sex  Household Head Age Household Head Marital Status  \
# 0             Female                  49                        Single
# 1               Male                  40                       Married
# 2               Male                  39                       Married
# 3               Male                  52                       Married
# 4               Male                  65                       Married
#
#              Household Head Highest Grade Completed  \
# 0  Teacher Training and Education Sciences Programs
# 1                       Transport Services Programs
# 2                                           Grade 3
# 3                               Elementary Graduate
# 4                               Elementary Graduate
#
#   Household Head Job or Business Indicator  \
# 0                        With Job/Business
# 1                        With Job/Business
# 2                        With Job/Business
# 3                        With Job/Business
# ...

# %%
clean_data = raw_data[[
    'Total Income',
    'Main Source of Income',
    'Total Food Expenditure',
    'Bread and Cereals Expenditure',
    'Total Rice Expenditure',
    'Meat Expenditure',
    'Total Fish and  marine products Expenditure',
    'Fruit Expenditure',
    'Vegetables Expenditure',
    'Restaurant and hotels Expenditure',
    'Alcoholic Beverages Expenditure',
    'Tobacco Expenditure',
    'Clothing, Footwear and Other Wear Expenditure',
    'Housing and water Expenditure',
    'Medical Care Expenditure',
    'Transportation Expenditure',
    'Communication Expenditure',
    'Education Expenditure',
    'Miscellaneous Goods and Services Expenditure',
    'Special Occasions Expenditure',
    'Crop Farming and Gardening expenses',
]]
clean_data.head()
# Out:
#    Total Income Main Source of Income  Total Food Expenditure  \
# 0        524702         Wage/Salaries                  117848
# 1        198235         Wage/Salaries                   67766
# 2         82785         Wage/Salaries                   61609
# 3        123169         Wage/Salaries                   78189
# 4        265009         Wage/Salaries                   94625
#
#    Bread and Cereals Expenditure  Total Rice Expenditure  Meat Expenditure  \
# 0                          42140                   38300             24676
# 1                          17329                   13008             17434
# 2                          34182                   32001              7783
# 3                          34030                   28659             10914
# 4                          34820                   30167             18391
#
#    Total Fish and  marine products Expenditure  Fruit Expenditure  \
# 0                                        16806               3325
# ...

# %%
new_names = [
    'Total Income',
    'Main Source of Income',
    'Food Expenditure',
    'Bread and Cereals Expenditure',
    'Rice Expenditure',
    'Meat Expenditure',
    'Fish and Marine Products Expenditure',
    'Fruit Expenditure',
    'Vegetables Expenditure',
    'Restaurant and Hotels Expenditure',
    'Alcoholic Beverages Expenditure',
    'Tobacco Expenditure',
    'Clothing and Other Wear Expenditure',
    'Housing and Water Expenditure',
    'Medical Care Expenditure',
    'Transportation Expenditure',
    'Communication Expenditure',
    'Education and Learning Expenditure',
    'Miscellaneous Expenditure',
    'Special Occasions Expenditure',
    'Gardening Expenditure',
]
clean_data.set_axis(new_names, axis="columns", inplace=True)

# %%
clean_data.tail()
# Out:
#        Total Income       Main Source of Income  Food Expenditure  \
# 41539        213893  Enterpreneurial Activities             44875
# 41540        215590  Enterpreneurial Activities             31157
# 41541        231716  Enterpreneurial Activities             45882
# 41542        236935  Enterpreneurial Activities             81416
# 41543        234145  Enterpreneurial Activities             78195
#
#        Bread and Cereals Expenditure  Rice Expenditure  Meat Expenditure  \
# 41539                          23675             21542              1476
# 41540                           2691              1273              1886
# 41541                          28646             27339               480
# 41542                          29996             26655              2359
# 41543                          43485             41205              1985
#
#        Fish and Marine Products Expenditure  Fruit Expenditure  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
corr_matrix = clean_data[new_names].corr()
fig, ax = plt.subplots(figsize=(15, 15))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', ax=ax)
plt.show()

# %%
clean_data['Savings'] = clean_data['Total Income'] - clean_data.iloc[:,2:].sum(axis=1)
clean_data.head(10)
# Out:
# /tmp/ipykernel_40469/2151471311.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data['Savings'] = clean_data['Total Income'] - clean_data.iloc[:,2:].sum(axis=1)
#    Total Income       Main Source of Income  Food Expenditure  \
# 0        524702               Wage/Salaries            117848
# 1        198235               Wage/Salaries             67766
# 2         82785               Wage/Salaries             61609
# 3        123169               Wage/Salaries             78189
# 4        265009               Wage/Salaries             94625
# 5        152883               Wage/Salaries             73326
# 6        270911               Wage/Salaries            104644
# ...

# %%
food_cols = ['Bread and Cereals Expenditure',
             'Rice Expenditure',
             'Meat Expenditure',
             'Fish and Marine Products Expenditure',
             'Fruit Expenditure',
             'Vegetables Expenditure',
             'Restaurant and Hotels Expenditure']

food_expenditure = clean_data[food_cols].sum(axis=1)

food_corr_data = pd.concat([clean_data[['Total Income', 'Savings', 'Food Expenditure']], food_expenditure], axis=1)

food_corr_data.columns = ['Total Income', 'Savings', 'Food Expenditure', 'Compound Food Expenditure']

food_corr = food_corr_data.corr()

# %%
food_corr
# Out:
#                            Total Income   Savings  Food Expenditure  \
# Total Income                   1.000000  0.873993          0.581342
# Savings                        0.873993  1.000000          0.184188
# Food Expenditure               0.581342  0.184188          1.000000
# Compound Food Expenditure      0.525591  0.135463          0.951160
#
#                            Compound Food Expenditure
# Total Income                                0.525591
# Savings                                     0.135463
# Food Expenditure                            0.951160
# Compound Food Expenditure                   1.000000

# %%
# Food Expenditure highly correlated with Break Down Expenses on Food.

# %%
food_corr_data.head(10)
# Out:
#    Total Income  Savings  Food Expenditure  Compound Food Expenditure
# 0        524702    88965            117848                     141707
# 1        198235   -55365             67766                      71072
# 2         82785   -95509             61609                      86626
# 3        123169  -100502             78189                      99272
# 4        265009   -17735             94625                     113742
# 5        152883   -47020             73326                      89812
# 6        270911   -94376            104644                     126967
# 7        186801  -131226             95644                     110875
# 8        171152    -5822             67348                      74266
# 9        938727   477732            158721                     182268

# %%
# Droppin break down details on food expenditure to avoid noise

clean_data = clean_data.drop(
    columns = [
        'Bread and Cereals Expenditure',
        'Rice Expenditure',
        'Meat Expenditure',
        'Fish and Marine Products Expenditure',
        'Fruit Expenditure',
        'Vegetables Expenditure',
    ], axis=1)

clean_data.head(10)
# Out:
#    Total Income       Main Source of Income  Food Expenditure  \
# 0        524702               Wage/Salaries            117848
# 1        198235               Wage/Salaries             67766
# 2         82785               Wage/Salaries             61609
# 3        123169               Wage/Salaries             78189
# 4        265009               Wage/Salaries             94625
# 5        152883               Wage/Salaries             73326
# 6        270911               Wage/Salaries            104644
# 7        186801     Other sources of Income             95644
# 8        171152     Other sources of Income             67348
# 9        938727  Enterpreneurial Activities            158721
#
#    Restaurant and Hotels Expenditure  Alcoholic Beverages Expenditure  \
# 0                               3000                                0
# 1                               2360                              960
# 2                               4545                              270
# ...

# %%
expenditure_sum = clean_data.iloc[:, 2:-1].sum(axis=1)

new_data = pd.DataFrame({'Total Income': clean_data['Total Income'], 
                         'Expenditure Sum': expenditure_sum, 
                         'Savings': clean_data['Savings']})

corr_matrix = new_data.corr()

# %%
corr_matrix
# Out:
#                  Total Income  Expenditure Sum   Savings
# Total Income         1.000000         0.752098  0.873993
# Expenditure Sum      0.752098         1.000000  0.344920
# Savings              0.873993         0.344920  1.000000

# %%
clean_data.tail()
# Out:
#        Total Income       Main Source of Income  Food Expenditure  \
# 41539        213893  Enterpreneurial Activities             44875
# 41540        215590  Enterpreneurial Activities             31157
# 41541        231716  Enterpreneurial Activities             45882
# 41542        236935  Enterpreneurial Activities             81416
# 41543        234145  Enterpreneurial Activities             78195
#
#        Restaurant and Hotels Expenditure  Alcoholic Beverages Expenditure  \
# 41539                               1805                                0
# 41540                               9090                                0
# 41541                               3330                                0
# 41542                              13660                                0
# 41543                               5750                                0
#
#        Tobacco Expenditure  Clothing and Other Wear Expenditure  \
# ...

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_absolute_error, silhouette_score

# define the features and target variable
X = clean_data.drop(columns=['Main Source of Income', 'Savings'], axis=1)
y = clean_data['Savings']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=2)

poly_features = PolynomialFeatures(degree=1, include_bias=False)
X_poly_train = poly_features.fit_transform(X_train)
X_poly_test = poly_features.fit_transform(X_test)

kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(X_poly_train)

# Predict the cluster labels for the testing set
X_pred_cluster = kmeans.predict(X_poly_test)

reg = LinearRegression()
reg.fit(X_poly_train, y_train)

y_pred_reg = reg.predict(X_poly_test)

# Evaluate the performance of the clustering model
silhouette_score = silhouette_score(X_test, X_pred_cluster)
print("Silhouette Score: {:.2f}".format(silhouette_score))

# # Evaluate the performance of the regression model
mae = mean_absolute_error(y_test, y_pred_reg)
print("Mean Absolute Error: {:.2f}".format(mae))

# %%
import joblib

# Expenditure weights
weights = {'Food Expenditure': 0.2,
           'Restaurant and Hotels Expenditure': 0.05,
           'Alcoholic Beverages Expenditure': 0.01,
           'Tobacco Expenditure': 0.01,
           'Clothing and Other Wear Expenditure': 0.04,
           'Housing and Water Expenditure': 0.3,
           'Medical Care Expenditure': 0.05,
           'Transportation Expenditure': 0.05,
           'Communication Expenditure': 0.1,
           'Education and Learning Expenditure': 0.1,
           'Miscellaneous Expenditure': 0.05,
           'Special Occasions Expenditure': 0.04,
           'Gardening Expenditure': 0.01
          }

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=2)

# perform clustering on the features
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(X_train)

joblib.dump(kmeans, 'clustering_model.pkl')

# Perform linear regression on each cluster
models = []
for i in range(3):
    X_cluster = X_train[kmeans.labels_ == i]
    y_cluster = y_train[kmeans.labels_ == i]
    model = LinearRegression()
    model.fit(X_cluster, y_cluster)
    models.append(model)
    joblib.dump(model, f'model_cluster_{i}.pkl')
    
# Ask user for their expenditures, income, and desired savings
print("Please enter your individual expenditures:")
expenditures = {}
for col in X.columns:
    if col != 'Total Income':
        expenditure = int(input(f"{col}: "))
        expenditures[col] = expenditure

income = float(input("Total Income: "))
savings = float(input("Desired Savings: "))

# Calculate maximum spending in each category based on income and weights
max_spending = {}
for col in weights:
    max_spending[col] = (income - savings) * weights[col]

# Create a DataFrame from the user input
user_df = pd.DataFrame.from_dict({'Total Income': [income], **expenditures, 'Savings': [savings]})

# Determine the cluster of the user
kmeans = joblib.load('clustering_model.pkl')
user_cluster = kmeans.predict(user_df.drop(['Savings'], axis=1))[0]

# Generate personalized recommendations based on the user's cluster
print("\nRecommendations:")
'''
    The model predicts what the user can save based oon their spendings and recommends how much to cut 
    and on what to get closer to the desired saving goal.

    It suggests cutting down on expenditures to meet the saving goal if the goal cannot be met.
    Or suggest you up your spending or increase your saving goals if the goals is met and there is money left.
'''
model = joblib.load(f'model_cluster_{user_cluster}.pkl')

user_savings = model.predict(user_df.drop(['Savings'], axis=1))[0]

savings_gap = savings - user_savings

if savings >= user_savings:
    savings_cut = savings_gap / savings
    saving_cut_percent = round(savings_cut * 100, 2)
    print(f"With your current spending habits you can only save approximately {user_savings}, that's a {saving_cut_percent}% cut")
    print(f"To meet the extra {savings_gap} please follow our recommendations")
else:
    savings_increase = savings_gap / savings
    savings_increase_percent = round(savings_increase * 100, 2)
    print(f"Based on your current spending habit you can up your saving goal by approximately {abs(savings_gap)} more, that's a {savings_increase_percent}% increase")
    print("Or follow our recommendation on how you can allocate more to your expenditures")

for col, expenditure in expenditures.items():
    if expenditure > 0:
        if expenditures[col] > max_spending[col]:
            overspending_reduction = (expenditures[col] - max_spending[col]) / expenditures[col]
            print(f"You are overspending in {col} by {round(overspending_reduction * 100, 2)}%. "
                  f"You should reduce your spending on {col} to {round(max_spending[col], 2)}.")
            continue
        elif expenditures[col] <= max_spending[col]:
            print(f"You are within your budget on {col}. No spending cuts needed.")
            weight = weights[col]
            max_reduction = (user_savings - savings) * weight / expenditure
            reduction = min(max_reduction, 1.0)
            saved = round(reduction * expenditure, 2)
            if savings >= user_savings:
                print(f"If you adjust your spending on {col} by {round(reduction * 100, 2)}%, you could save {abs(saved)} more per month.")
            else:
                print(f"You could allocate {saved} more money on {col}, that's a {round(reduction * 100, 2)}% increase per month")
# Out:
# Please enter your individual expenditures:
# Food Expenditure: 290000
# Restaurant and Hotels Expenditure: 120000
# Alcoholic Beverages Expenditure: 24000
# Tobacco Expenditure: 24000
# Clothing and Other Wear Expenditure: 96000
# Housing and Water Expenditure: 725000
# Medical Care Expenditure: 29000
# Transportation Expenditure: 29000
# Communication Expenditure: 29000
# Education and Learning Expenditure: 29000
# Miscellaneous Expenditure: 29000
# Special Occasions Expenditure: 29000
# Gardening Expenditure: 0
# Total Income: 2900000
# Desired Savings: 483333
#
# Recommendations:
# Based on your current spending habit you can up your saving goal by approximately 820854.9342127703 more, that's a -169.83% increase
# Or follow our recommendation on how you can allocate more to your expenditures
# You are within your budget on Food Expenditure. No spending cuts needed.
# You could allocate 164170.99 more money on Food Expenditure, that's a 56.61% increase per month
# ...
